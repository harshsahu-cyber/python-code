# %%
#Create 5 variable with diifrent values and print them using print() function 
var_1=65
var_2="hindustan"
var_3=98.9
var_4=522
var_5=True
print(var_1)
print(var_2)
print(var_3)
print(var_4)
print(var_5)
# Out:
# 65
# hindustan
# 98.9
# 522
# True
